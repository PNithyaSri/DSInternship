# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Data Collection

# %%
data1=pd.read_csv(r"C:\Users\Nithya\Downloads\reviews_data_dump\reviews_tea\data.csv")

# %%
tea = data1.copy()

# %%
data2=pd.read_csv(r"C:\Users\Nithya\Downloads\reviews_data_dump\reviews_tawa\data.csv")

# %%
tawa = data2.copy()

# %%
data3=pd.read_csv(r"C:\Users\Nithya\Downloads\reviews_data_dump\reviews_badminton\data.csv")

# %%
badminton = data3.copy()

# %% [markdown]
# ### Data Exploration

# %%
tea.head()
# Out:
#        reviewer_name  reviewer_rating        review_title  \
# 0   Subhro  Banerjee                5   Worth every penny
# 1  Shiv chandra  Jha                5       Great product
# 2  Flipkart Customer                5  Highly recommended
# 3              DTH Y                4           Very Good
# 4    Bhavesh Godhani                5      Classy product
#
#                                          review_text  \
# 0  Great product 🤗 with great deals 😍😍 Tata Tea G...
# 1  Very nice and super qwality tea taste are grea...
# 2  Great test great quality great price point tim...
# 3                                    Nice 😊READ MORE
# 4               Very Good Tata tea product.READ MORE
#
#                    place_of_review     Date_of_review  up_votes  Down_votes
# 0     Certified Buyer, Budge Budge   Subhro  Banerjee       236          59
# 1         Certified Buyer, Saharsa  Shiv chandra  Jha       225          79
# 2  Certified Buyer, Sri Ganganagar  Flipkart Customer        89          27
# 3         Certified Buyer, Phaltan              DTH Y        30           6
# 4       Certified Buyer, Ahmedabad    Bhavesh Godhani        69          22

# %%
tea.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9170 entries, 0 to 9169
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   reviewer_name    9170 non-null   object
#  1   reviewer_rating  9170 non-null   int64
#  2   review_title     9170 non-null   object
#  3   review_text      9170 non-null   object
#  4   place_of_review  9170 non-null   object
#  5   Date_of_review   9170 non-null   object
#  6   up_votes         9170 non-null   int64
#  7   Down_votes       9170 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 573.2+ KB

# %%
tawa.head()
# Out:
#      Reviewer_Name  Reviewer_Rating           Review_Title  \
# 0     Sumit  Kumar              5.0              Wonderful
# 1  BHARAT GALAGALI              5.0  Mind-blowing purchase
# 2  Paramjeet Singh              5.0                Awesome
# 3  Virendra  Kumar              5.0          Great product
# 4    jyoti solanki              5.0    Best in the market!
#
#                                          Review_Text  \
# 0  I think In this price category it's best dosa ...
# 1                   perfect tawa for Dosa..READ MORE
# 2  Excellent tawa. Made Paneer Tikka on first day...
# 3                            Nice 🙂 productREAD MORE
# 4             Delivery man is also good....READ MORE
#
#                           Place_of_Review   Date_of_Review  Up_Votes  \
# 0             Certified Buyer, Lakhisarai     Sumit  Kumar       211
# 1                 Certified Buyer, Hunsur  BHARAT GALAGALI       107
# 2           Certified Buyer, Rampura Phul  Paramjeet Singh        59
# 3  Certified Buyer, Chengalpattu District  Virendra  Kumar        77
# 4                 Certified Buyer, Mumbai    jyoti solanki        53
#
#    Down_Votes
# 0          39
# 1          17
# 2           8
# 3          12
# 4           7

# %%
tawa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2531 entries, 0 to 2530
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Reviewer_Name    2531 non-null   object
#  1   Reviewer_Rating  2285 non-null   float64
#  2   Review_Title     2531 non-null   object
#  3   Review_Text      2531 non-null   object
#  4   Place_of_Review  2531 non-null   object
#  5   Date_of_Review   2531 non-null   object
#  6   Up_Votes         2531 non-null   int64
#  7   Down_Votes       2531 non-null   int64
# dtypes: float64(1), int64(2), object(5)
# memory usage: 158.3+ KB

# %%
badminton.head()
# Out:
#             Reviewer Name               Review Title  \
# 0            Kamal Suresh               Nice product
# 1       Flipkart Customer     Don't waste your money
# 2  A. S. Raja Srinivasan   Did not meet expectations
# 3     Suresh Narayanasamy                       Fair
# 4               ASHIK P A                Over priced
#
#                Place of Review  Up Votes  Down Votes     Month  \
# 0   Certified Buyer, Chirakkal     889.0        64.0  Feb 2021
# 1   Certified Buyer, Hyderabad     109.0         6.0  Feb 2021
# 2  Certified Buyer, Dharmapuri      42.0         3.0  Apr 2021
# 3     Certified Buyer, Chennai      25.0         1.0       NaN
# 4                          NaN     147.0        24.0  Apr 2016
#
#                                          Review text  Ratings
# 0  Nice product, good quality, but price is now r...        4
# 1  They didn't supplied Yonex Mavis 350. Outside ...        1
# 2  Worst product. Damaged shuttlecocks packed in ...        1
# 3  Quite O. K. , but nowadays  the quality of the...        3
# 4  Over pricedJust â?¹620 ..from retailer.I didn'...        1

# %%
badminton.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8518 entries, 0 to 8517
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Reviewer Name    8508 non-null   object
#  1   Review Title     8508 non-null   object
#  2   Place of Review  8468 non-null   object
#  3   Up Votes         8508 non-null   float64
#  4   Down Votes       8508 non-null   float64
#  5   Month            8053 non-null   object
#  6   Review text      8510 non-null   object
#  7   Ratings          8518 non-null   int64
# dtypes: float64(2), int64(1), object(5)
# memory usage: 532.5+ KB

# %% [markdown]
# ### Data Cleaning

# %%
tea = tea.drop("Date_of_review",axis=1)
tawa = tawa.drop("Date_of_Review",axis=1)

# %%
badminton["Up Votes"] = badminton["Up Votes"].fillna(0).astype("int64")
badminton["Down Votes"] = badminton["Down Votes"].fillna(0).astype("int64")
badminton["Month"] = badminton["Month"].fillna(0).astype("datetime64")

# %%
tea.isnull().sum()
# Out:
# reviewer_name      0
# reviewer_rating    0
# review_title       0
# review_text        0
# place_of_review    0
# up_votes           0
# Down_votes         0
# dtype: int64

# %%
tawa.isnull().sum()
# Out:
# Reviewer_Name        0
# Reviewer_Rating    246
# Review_Title         0
# Review_Text          0
# Place_of_Review      0
# Up_Votes             0
# Down_Votes           0
# dtype: int64

# %%
tawa["Reviewer_Rating"] = tawa["Reviewer_Rating"].fillna(0)

# %%
tawa.isnull().sum()
# Out:
# Reviewer_Name      0
# Reviewer_Rating    0
# Review_Title       0
# Review_Text        0
# Place_of_Review    0
# Up_Votes           0
# Down_Votes         0
# dtype: int64

# %%
badminton.isnull().sum()
# Out:
# Reviewer Name      10
# Review Title       10
# Place of Review    50
# Up Votes            0
# Down Votes          0
# Month               0
# Review text         8
# Ratings             0
# dtype: int64

# %%
badminton = badminton.fillna("Not Available")

# %%
badminton.isnull().sum()
# Out:
# Reviewer Name      0
# Review Title       0
# Place of Review    0
# Up Votes           0
# Down Votes         0
# Month              0
# Review text        0
# Ratings            0
# dtype: int64

# %%
tea.duplicated().sum()
# Out:
# 9159

# %%
tawa.duplicated().sum()
# Out:
# 60

# %%
badminton.duplicated().sum()
# Out:
# 4

# %% [markdown]
# ### EDA

# %%
sns.pairplot(tea)
plt.show()

# %%
bl = sns.barplot(x=tea["reviewer_rating"], y=tea['review_title'])
bl.bar_label(bl.containers[0], fontsize=10)
plt.title("title vs rating")
plt.show()

# %%
sns.barplot(x=tea['up_votes'], y=tea['review_title'], label="Up votes")
sns.barplot(x=tea['Down_votes'], y=tea['review_title'], label="Down votes")
plt.title("title vs Votes")
plt.legend()
plt.show()

# %%
bl = sns.barplot(x=tea["reviewer_rating"], y=tea['place_of_review'])
bl.bar_label(bl.containers[0], fontsize=10)
plt.title("place_of_review vs rating")
plt.show()

# %%
plt.figure(figsize=(10,15))
bl = sns.countplot(tawa["Review_Title"])
bl.bar_label(bl.containers[0], fontsize=10)
plt.title("Review Titles")
plt.show()

# %%
sns.pairplot(tawa)
plt.show()

# %%
plt.figure(figsize=(10,15))
bl = sns.barplot(x=tawa["Reviewer_Rating"], y=tawa['Review_Title'])
bl.bar_label(bl.containers[0], fontsize=10)
plt.title("title vs rating")
plt.show()

# %%
plt.figure(figsize=(10,15))
sns.barplot(x=tawa['Up_Votes'], y=tawa['Review_Title'], label="Up votes")
sns.barplot(x=tawa['Down_Votes'], y=tawa['Review_Title'], label="Down votes")
plt.title("title vs Votes")
plt.legend()
plt.show()

# %%
sns.pairplot(badminton)
plt.show()

# %% [markdown]
# ### Split the dataset

# %%
fv = pd.concat([tea["review_text"], tawa['Review_Text'], badminton['Review text']], ignore_index=True)

# %%
cv = pd.concat([tea["reviewer_rating"], tawa["Reviewer_Rating"], badminton["Ratings"]], ignore_index=True)

# %%
cv.value_counts()
# Out:
# 5.0    12907
# 4.0     4169
# 1.0     1686
# 3.0      903
# 2.0      308
# 0.0      246
# dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(fv,cv,test_size=0.2,random_state=3,stratify=cv)

# %% [markdown]
# ### Data Preprocessing

# %%
import regex as re
from textblob import TextBlob
import emoji

import nltk
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

# %%
def preprocess_text(series):
    # Ensure input is a pandas Series object
    if not isinstance(series, pd.Series):
        raise ValueError("Input must be a pandas Series object.")
    
    # Convert non-string values to strings
    series = series.astype(str)
    
    # Convert to lowercase
    series = series.str.lower()
    
    # Remove HTML tags
    series = series.apply(lambda x: re.sub(r'<[^>]*>', '', x))
    
    # Remove URLs
    series = series.apply(lambda x: re.sub(r'http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\\(\\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+', '', x))
    
    # Remove punctuation
    series = series.apply(lambda x: re.sub(r'[^\w\s]', '', x))
    
    # Remove stop words
    stop_words = set(stopwords.words('english'))
    series = series.apply(lambda x: ' '.join([word for word in word_tokenize(x) if word not in stop_words]))
    
    # Remove float values
    series = series.apply(lambda x: re.sub(r'\b\d+\.\d+\b', '', x))
    
    # Lemmatization
    lemmatizer = WordNetLemmatizer()
    series = series.apply(lambda x: ' '.join([lemmatizer.lemmatize(word) for word in word_tokenize(x)]))
    
    return series

# %%
preprocess_text(x_train)
# Out:
# 1704                             good tata tea productread
# 13951                                     good qualityread
# 15352                                            superread
# 5689                                      good productread
# 12596                                              badread
#                                ...
# 8448     believe best packaged tea market taste somethi...
# 4740     great product great deal tata tea gold best ti...
# 4355                           nice red teavaleu moneyread
# 13893          usual awesome best among shuttle brandsread
# 13797                best nylon shuttle outdoor indoorread
# Length: 16175, dtype: object

# %% [markdown]
# ### EDA

# %%
from collections import Counter

# %%
Counter("".join(preprocess_text(x_train)).split()).most_common(10)
# Out:
# [('tea', 6555),
#  ('product', 2473),
#  ('price', 2403),
#  ('best', 2299),
#  ('tata', 2199),
#  ('great', 2194),
#  ('gold', 2186),
#  ('quality', 2001),
#  ('long', 1502),
#  ('high', 1491)]

# %% [markdown]
# These are the top ten most occuring words in x_train

# %%
Counter("".join(preprocess_text(x_test)).split()).most_common(10)
# Out:
# [('tea', 1698),
#  ('best', 631),
#  ('product', 613),
#  ('great', 607),
#  ('price', 599),
#  ('gold', 566),
#  ('tata', 552),
#  ('quality', 537),
#  ('long', 416),
#  ('packaging', 403)]

# %% [markdown]
# Ten most occuring words in x_test

# %%
from wordcloud import WordCloud

# %%
wc=WordCloud().generate(" ".join(preprocess_text(x_train)))
plt.imshow(wc)
plt.show()

# %%
wc=WordCloud().generate(" ".join(preprocess_text(x_test)))
plt.imshow(wc)
plt.show()

# %% [markdown]
# ### Feature Engineering

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import FunctionTransformer
from sklearn.feature_extraction.text import CountVectorizer

# %%
bow_on_pptext=Pipeline([("Pre-process",FunctionTransformer(preprocess_text)),("bagofwords",CountVectorizer())])
bow_on_pptext
# Out:
# Pipeline(steps=[('Pre-process',
#                  FunctionTransformer(func=<function preprocess_text at 0x00000196118FED40>)),
#                 ('bagofwords', CountVectorizer())])

# %%
bow_on_pptext.fit_transform(x_train)
# Out:
# <16175x3995 sparse matrix of type '<class 'numpy.int64'>'
# 	with 99592 stored elements in Compressed Sparse Row format>

# %% [markdown]
# ### Model Training

# %%
from sklearn.naive_bayes import MultinomialNB

# %%
b=MultinomialNB()

# %%
final_model=b.fit(bow_on_pptext.fit_transform(x_train),y_train)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression()

# %%
model = lr.fit(bow_on_pptext.fit_transform(x_train),y_train)
# Out:
# C:\Users\Nithya\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %% [markdown]
# ### Accuracy

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,final_model.predict(bow_on_pptext.transform(x_test)))
# Out:
# 0.6906528189910979

# %%
accuracy_score(y_test,model.predict(bow_on_pptext.transform(x_test)))
# Out:
# 0.7786844708209694

# %% [markdown]
# ### Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report

# %%
confusion_matrix(y_test,model.predict(bow_on_pptext.transform(x_test)))
# Out:
# array([[  13,   11,    0,    9,    3,   13],
#        [   1,  263,    9,   10,    6,   48],
#        [   0,   20,    3,    6,    7,   26],
#        [   2,   11,    0,   39,   32,   97],
#        [   1,   10,    2,   33,  436,  352],
#        [   0,   10,    2,   18,  156, 2395]], dtype=int64)

# %%
ConfusionMatrixDisplay(confusion_matrix(y_test,model.predict(bow_on_pptext.transform(x_test)))).plot()
plt.show()

# %%
print(classification_report(y_test,model.predict(bow_on_pptext.transform(x_test))))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.76      0.27      0.39        49
#          1.0       0.81      0.78      0.79       337
#          2.0       0.19      0.05      0.08        62
#          3.0       0.34      0.22      0.26       181
#          4.0       0.68      0.52      0.59       834
#          5.0       0.82      0.93      0.87      2581
#
#     accuracy                           0.78      4044
#    macro avg       0.60      0.46      0.50      4044
# weighted avg       0.76      0.78      0.76      4044

# %% [markdown]
# ### Deployment

# %%
import pickle

# %%
pickle.dump(model,open(r"C:\Users\Nithya\Videos\flipkartProducts-sentimentanalysis.pkl","wb"))

# %%
pickle.dump(bow_on_pptext,open(r"C:\Users\Nithya\Videos\flipkartProducts-bow_on_pptext.pkl","wb"))
